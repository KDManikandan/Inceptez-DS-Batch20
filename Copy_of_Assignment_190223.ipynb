# %% [markdown]
# <a href="https://colab.research.google.com/github/KDManikandan/Inceptez-DS-Batch20/blob/main/Copy_of_Assignment_190223.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
demand=pd.read_csv("https://raw.githubusercontent.com/KDManikandan/Inceptez-DS-Batch20/main/12.%20Preprocessing/Demand_txn_updated.csv")

# %%
demand.head(16)
# Out:
#          City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 0   Hyderabad         Take Away              9978        7/31/2018
# 1   Hyderabad         Take Away              4064        7/31/2018
# 2   Hyderabad         Main Hall               965        7/31/2018
# 3   Hyderabad           Express              9978        7/31/2018
# 4   Hyderabad           Express              1045        7/31/2018
# 5   Hyderabad          Delivery              4056        7/31/2018
# 6   Hyderabad         Take Away              4065        7/31/2018
# 7   Hyderabad           Express              4058        7/31/2018
# 8   Hyderabad           Express              4057        7/31/2018
# 9   Hyderabad           Express              4056        7/31/2018
# 10  Hyderabad          Delivery              4061        7/31/2018
# 11  Hyderabad           Express              4055        7/31/2018
# 12  Hyderabad         Take Away              4061        7/31/2018
# ...

# %% [markdown]
# 2. Convert the transaction date column to a date column using pd.to_datetime function

# %%
demand.dtypes
# Out:
# City                                           object
# Mapped_Sales_Type                              object
# Mapped_Item_Code                                int64
# Transaction_Date                               object
# Quantity_Sold                                   int64
# Median_Price                                  float64
# Average_Tax_Percent                           float64
# Effective_Price                               float64
# Percent_Quantity_With_Discount                float64
# Avg_Discount_Percent_On_Discounted_Items      float64
# Year                                            int64
# Month                                           int64
# Day                                            object
# Car_sales                                     float64
# F_and_B_Inflation                             float64
# F_and_B_Inflation_Adjusted_Effective_Price    float64
# F_and_B_Inflation_Adjusted_Median_Price       float64
# ...

# %%
demand['Transaction_Date']=demand['Transaction_Date'].astype('datetime64')

# %%
demand.dtypes
# Out:
# City                                                  object
# Mapped_Sales_Type                                     object
# Mapped_Item_Code                                       int64
# Transaction_Date                              datetime64[ns]
# Quantity_Sold                                          int64
# Median_Price                                         float64
# Average_Tax_Percent                                  float64
# Effective_Price                                      float64
# Percent_Quantity_With_Discount                       float64
# Avg_Discount_Percent_On_Discounted_Items             float64
# Year                                                   int64
# Month                                                  int64
# Day                                                   object
# Car_sales                                            float64
# F_and_B_Inflation                                    float64
# ...

# %% [markdown]
# 3. Subset the dataframe for transaction date greater than '2016-08-01'

# %%
import numpy as np

# %% [markdown]
# 3.ubset the dataframe for transaction date greater than '2016-08-01'

# %%
demand1=demand[demand.Transaction_Date > '2016=08-01']
demand1.head()
# Out:
#         City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 0  Hyderabad         Take Away              9978        7/31/2018
# 1  Hyderabad         Take Away              4064        7/31/2018
# 2  Hyderabad         Main Hall               965        7/31/2018
# 3  Hyderabad           Express              9978        7/31/2018
# 4  Hyderabad           Express              1045        7/31/2018
#
#    Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# 0            167         187.0                 0.05       163.700000
# 1            368         602.0                 0.05       584.329105
# 2            694         263.0                 0.05       244.835163
# 3            140         263.0                 0.05       243.500000
# 4            139         392.0                 0.05       378.960000
#
#    Percent_Quantity_With_Discount  Avg_Discount_Percent_On_Discounted_Items  \
# ...

# %% [markdown]
# 4.Look for unique values in Mapped_Sales_Type

# %%
unique_values = demand['Mapped_Sales_Type'].unique()
print(unique_values)
# Out:
# ['Take Away' 'Main Hall' 'Express' 'Delivery' 'Dine-in' 'Bakery']

# %% [markdown]
# 5.Subset the entire dataframe, based on the below condition, to a new dataframe and work
# on the following questions
# a. Condition: Avg_Discount_Percent_On_Discounted_Items should be less than 1.0
# b. Check for sanity if the new dataframe contains
# Avg_Discount_Percent_On_Discounted_Items greater than or equal to 1.0

# %%
data_subset = demand[demand['Avg_Discount_Percent_On_Discounted_Items'] < 1.0]
print(data_subset)
# Out:
#             City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 5      Hyderabad          Delivery              4056        7/31/2018
# 10     Hyderabad          Delivery              4061        7/31/2018
# 20     Hyderabad           Dine-in               966        7/31/2018
# 24     Hyderabad           Dine-in               965        7/31/2018
# 26     Hyderabad          Delivery              4068        7/31/2018
# ...          ...               ...               ...              ...
# 30198     Mumbai         Take Away              4055         8/1/2016
# 30201     Mumbai           Dine-in               978         8/1/2016
# 30212     Mumbai           Dine-in               970         8/1/2016
# 30213     Mumbai           Dine-in               965         8/1/2016
# 30226     Mumbai         Take Away              4056         8/1/2016
#
#        Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# ...

# %%
sanity_check = data_subset[data_subset['Avg_Discount_Percent_On_Discounted_Items'] >= 1.0]
print(sanity_check)
# Out:
# Empty DataFrame
# Columns: [City, Mapped_Sales_Type, Mapped_Item_Code, Transaction_Date, Quantity_Sold, Median_Price, Average_Tax_Percent, Effective_Price, Percent_Quantity_With_Discount, Avg_Discount_Percent_On_Discounted_Items, Year, Month, Day, Car_sales, F_and_B_Inflation, F_and_B_Inflation_Adjusted_Effective_Price, F_and_B_Inflation_Adjusted_Median_Price, First_Week_Of_The_Month_Dummy, Last_Week_Of_The_Month_Dummy, Day_Of_The_Week_Seasonality, Month_Of_The_Year_Seasonality, Two_Wheeler_sales]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# 6.Groupby 'City', 'Mapped_Sales_Type', 'Mapped_Item_Code', 'Transaction_Date' and
# perform following aggregate operations on respective columns as mentioned (note: Only
# one groupby to do all the below aggregations) - Quantity_sold(sum)

# %%
demand.groupby(['City','Mapped_Sales_Type','Mapped_Item_Code','Transaction_Date'])['Quantity_Sold'].agg(np.sum)
# Out:
# City     Mapped_Sales_Type  Mapped_Item_Code  Transaction_Date
# Chennai  Bakery             4057              8/5/2017            110
#                             9978              1/22/2018           105
#          Delivery           4055              1/1/2018            714
#                                               1/10/2018           567
#                                               1/11/2018           499
#                                                                  ...
# Mumbai   Take Away          4068              9/5/2016            200
#                                               9/6/2016            210
#                                               9/7/2016            209
#                                               9/8/2016            193
#                                               9/9/2016            256
# Name: Quantity_Sold, Length: 30231, dtype: int64

# %% [markdown]
# 6.Groupby 'City', 'Mapped_Sales_Type', 'Mapped_Item_Code', 'Transaction_Date' and
# perform following aggregate operations on respective columns as mentioned (note: Only
# one groupby to do all the below aggregations) - Median_Price – median

# %%
demand.groupby(['City','Mapped_Sales_Type','Mapped_Item_Code','Transaction_Date'])['Median_Price'].agg(np.median)
# Out:
# City     Mapped_Sales_Type  Mapped_Item_Code  Transaction_Date
# Chennai  Bakery             4057              8/5/2017            223.0
#                             9978              1/22/2018           178.0
#          Delivery           4055              1/1/2018            281.1
#                                               1/10/2018           281.1
#                                               1/11/2018           281.1
#                                                                   ...
# Mumbai   Take Away          4068              9/5/2016            405.0
#                                               9/6/2016            405.0
#                                               9/7/2016            405.0
#                                               9/8/2016            405.0
#                                               9/9/2016            405.0
# Name: Median_Price, Length: 30231, dtype: float64

# %% [markdown]
# 6.Groupby 'City', 'Mapped_Sales_Type', 'Mapped_Item_Code', 'Transaction_Date' and perform following aggregate operations on respective columns as mentioned (note: Only one groupby to do all the below aggregations) -  Effective_Price – median

# %%
demand.groupby(['City','Mapped_Sales_Type','Mapped_Item_Code','Transaction_Date'])['Effective_Price'].agg(np.median)
# Out:
# City     Mapped_Sales_Type  Mapped_Item_Code  Transaction_Date
# Chennai  Bakery             4057              8/5/2017            221.000000
#                             9978              1/22/2018           154.250000
#          Delivery           4055              1/1/2018            262.466899
#                                               1/10/2018           262.359057
#                                               1/11/2018           262.446314
#                                                                      ...
# Mumbai   Take Away          4068              9/5/2016            424.140000
#                                               9/6/2016            424.140000
#                                               9/7/2016            424.140000
#                                               9/8/2016            424.140000
#                                               9/9/2016            424.140000
# Name: Effective_Price, Length: 30231, dtype: float64

# %% [markdown]
# 7.Display the data for Effective_Price = not null and just print the last 5 rows (hint: use .notnull
# function)

# %%
filtered_data = demand[demand['Effective_Price'].notnull()].tail(5)
print(filtered_data)
# Out:
#          City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 30226  Mumbai         Take Away              4056         8/1/2016
# 30227  Mumbai         Take Away              4058         8/1/2016
# 30228  Mumbai           Dine-in               964         8/1/2016
# 30229  Mumbai         Take Away              4066         8/1/2016
# 30230  Mumbai          Delivery              4061         8/1/2016
#
#        Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# 30226            615         239.0                 0.14       232.033552
# 30227           1289         212.8                 0.14       202.575840
# 30228            140         933.0                 0.21      1063.855517
# 30229            179         501.0                 0.14       534.060000
# 30230            117         716.5                 0.15       780.810000
#
#        Percent_Quantity_With_Discount  \
# 30226                        0.013889
# 30227                        0.009338
# ...

# %% [markdown]
# 8. Display the data for city = Chennai AND Mapped_Sales_Type = Delivery and print top 5
# records (hint use loc function to subset, then “&” operator to filter both the above cities)

# %%
filtered_data = demand.loc[(demand['City'] == 'Chennai') & (demand['Mapped_Sales_Type'] == 'Delivery')].head(5)
print(filtered_data)
# Out:
#          City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 8379  Chennai          Delivery              4055         2/5/2018
# 8384  Chennai          Delivery              4068         2/5/2018
# 8387  Chennai          Delivery              4064         2/5/2018
# 8388  Chennai          Delivery              4058         2/5/2018
# 8392  Chennai          Delivery              4061         2/5/2018
#
#       Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# 8379            544        281.10                 0.05       262.502194
# 8384            129        566.43                 0.05       562.110000
# 8387            186        619.34                 0.05       617.659733
# 8388            287        259.19                 0.05       239.381307
# 8392            128        850.62                 0.05       855.697647
#
#       Percent_Quantity_With_Discount  \
# 8379                             NaN
# 8384                             NaN
# ...

# %% [markdown]
# 9.Display the data for the column “Day” with values Mon, Tue and Wed (hint: use .isin
# function)

# %%
filtered_data = demand[demand['Day'].isin(['Mon', 'Tue', 'Wed'])]
print(filtered_data)
# Out:
#             City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 0      Hyderabad         Take Away              9978        7/31/2018
# 1      Hyderabad         Take Away              4064        7/31/2018
# 2      Hyderabad         Main Hall               965        7/31/2018
# 3      Hyderabad           Express              9978        7/31/2018
# 4      Hyderabad           Express              1045        7/31/2018
# ...          ...               ...               ...              ...
# 30226     Mumbai         Take Away              4056         8/1/2016
# 30227     Mumbai         Take Away              4058         8/1/2016
# 30228     Mumbai           Dine-in               964         8/1/2016
# 30229     Mumbai         Take Away              4066         8/1/2016
# 30230     Mumbai          Delivery              4061         8/1/2016
#
#        Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# ...

# %% [markdown]
# 10. Display the data for Percent_Quantity_With_Discount not equal to 0.0 (hint: loc function
# with != operator)

# %%
percent_quality = demand.loc[demand['Percent_Quantity_With_Discount'] != 0.0]

# %%
print(percent_quality)
# Out:
#             City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 0      Hyderabad         Take Away              9978        7/31/2018
# 1      Hyderabad         Take Away              4064        7/31/2018
# 2      Hyderabad         Main Hall               965        7/31/2018
# 3      Hyderabad           Express              9978        7/31/2018
# 4      Hyderabad           Express              1045        7/31/2018
# ...          ...               ...               ...              ...
# 30226     Mumbai         Take Away              4056         8/1/2016
# 30227     Mumbai         Take Away              4058         8/1/2016
# 30228     Mumbai           Dine-in               964         8/1/2016
# 30229     Mumbai         Take Away              4066         8/1/2016
# 30230     Mumbai          Delivery              4061         8/1/2016
#
#        Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# ...

# %% [markdown]
# 11.Add a column “Range” to the existing dataframe for below condition
# a. 1 for Effective_Price > 500
# b. 0.5 otherwise

# %%
def get_range(x):
    if x['Effective_Price'] > 500:
        return 1
    else:
        return 0.5

# %%
demand['Range'] = demand.apply(get_range, axis=1)

# %%
print(demand)
# Out:
#             City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 0      Hyderabad         Take Away              9978        7/31/2018
# 1      Hyderabad         Take Away              4064        7/31/2018
# 2      Hyderabad         Main Hall               965        7/31/2018
# 3      Hyderabad           Express              9978        7/31/2018
# 4      Hyderabad           Express              1045        7/31/2018
# ...          ...               ...               ...              ...
# 30226     Mumbai         Take Away              4056         8/1/2016
# 30227     Mumbai         Take Away              4058         8/1/2016
# 30228     Mumbai           Dine-in               964         8/1/2016
# 30229     Mumbai         Take Away              4066         8/1/2016
# 30230     Mumbai          Delivery              4061         8/1/2016
#
#        Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# ...

# %% [markdown]
# 12. Read the demand transaction file again and perform following operations for practice
# a. Handle the missing values in the column Percent_Quantity_With_Discount with
# strategy = mean
# b. One hot encode the columns Mapped_Sales_Type
# c. Label binarize the column Day
# d. Label encode the column City
